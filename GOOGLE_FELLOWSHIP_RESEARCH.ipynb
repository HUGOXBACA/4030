# %% [markdown]
# <a href="https://colab.research.google.com/github/HUGOXBACA/ANALOG-CIRCUIT-DESIGN-ANALYSIS-4030/blob/main/GOOGLE_FELLOWSHIP_RESEARCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Rail Grade-Crossing Safety***
#
# August 5th, 2023: Hugo: I have found some Federal DOT public data that seems interesting. Therefore I will be doing some exploratory data analysis on this data set and see what I find.
#
# Link to dataset: [Highway-Rail Grade Crossing Accident Data](https://data.transportation.gov/Railroads/Highway-Rail-Grade-Crossing-Accident-Data-Form-57-/7wn6-i5b9)

# %%
# !pip install pandas
# !pip install sodapy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting sodapy
#   Downloading sodapy-2.2.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: requests>=2.28.1 in /usr/local/lib/python3.10/dist-packages (from sodapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->sodapy) (2023.7.22)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.2.0

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.transportation.gov", None)

#client = Socrata( data.transportation.gov,
 #                 '1hCte9vYL7IpE7pFTGR1cbn8y',
  #                username="hugo.baca4515@coyote.csusb.edu",
   #               password="")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("7wn6-i5b9", limit=20)

# Convert to pandas DataFrame
HRGC_data_raw = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#let's see what we get back
print(HRGC_data_raw)
# Out:
#    railroadcode                               railroadname  year  \
# 0            SP    Southern Pacific Transportation Company  1986
# 1          CAGY      Columbus & Greenville Railway Company  1986
# 2          CAGY      Columbus & Greenville Railway Company  1986
# 3           SOU                   SOUTHERN RAILWAY COMPANY  1976
# 4          GSMR  GULF AND MISSISSIPPI RAILROAD CORPORATION  1986
# 5           ICG     Illinois Central Gulf Railroad Company  1986
# 6          MSRC              MIDSOUTH RAILROAD CORPORATION  1986
# 7           ICG     Illinois Central Gulf Railroad Company  1986
# 8           ICG     Illinois Central Gulf Railroad Company  1986
# 9           ICG     Illinois Central Gulf Railroad Company  1986
# 10          ICG     Illinois Central Gulf Railroad Company  1986
# 11          ICG     Illinois Central Gulf Railroad Company  1986
# 12         GSMR  GULF AND MISSISSIPPI RAILROAD CORPORATION  1986
# 13          ICG     Illinois Central Gulf Railroad Company  1986
# 14         GSMR  GULF AND MISSISSIPPI RAILROAD CORPORATION  1986
# 15         GSMR  GULF AND MISSISSIPPI RAILROAD CORPORATION  1986
# 16         MSRC              MIDSOUTH RAILROAD CORPORATION  1986
# 17         GSMR  GULF AND MISSISSIPPI RAILROAD CORPORATION  1986
# 18         MSRC              MIDSOUTH RAILROAD CORPORATION  1986
# 19         GSMR  GULF AND MISSISSIPPI RAILROAD CORPORATION  1986
#
#    incidentnumber incidentyear incidentmonth maintenancerailroadcode  \
# 0           F3166           86            05                      SP
# 1           86038           86            06                    CAGY
# 2           86049           86            06                    CAGY
# 3       GC0676045           76            07                     NaN
# 4         GM92799           86            07                    GSMR
# 5           95359           86            07                     ICG
# 6           C0709           86            07                    MSRC
# 7           95354           86            07                     ICG
# 8           95363           86            07                     ICG
# 9           95362           86            07                     ICG
# 10          95365           86            07                     ICG
# 11          20165           86            07                     ICG
# 12       GM927100           86            07                    GSMR
# 13          95364           86            07                     ICG
# 14        GM92797           86            07                    GSMR
# 15        GM92798           86            07                    GSMR
# 16          CO605           86            06                    MSRC
# 17          92795           86            06                    GSMR
# 18          CO607           86            06                    MSRC
# 19          92796           86            06                    GSMR
#
#                       maintenancerailroadname maintainenanceincidentnumber  \
# 19                          Not Assigned
#
#                                                   url  \
# 0   {'url': 'https://safetydata.fra.dot.gov/Office...
# 1   {'url': 'https://safetydata.fra.dot.gov/Office...
# 2   {'url': 'https://safetydata.fra.dot.gov/Office...
# 3   {'url': 'https://safetydata.fra.dot.gov/Office...
# 4   {'url': 'https://safetydata.fra.dot.gov/Office...
# 5   {'url': 'https://safetydata.fra.dot.gov/Office...
# 6   {'url': 'https://safetydata.fra.dot.gov/Office...
# 7   {'url': 'https://safetydata.fra.dot.gov/Office...
# 8   {'url': 'https://safetydata.fra.dot.gov/Office...
# 9   {'url': 'https://safetydata.fra.dot.gov/Office...
# 10  {'url': 'https://safetydata.fra.dot.gov/Office...
# 11  {'url': 'https://safetydata.fra.dot.gov/Office...
# 12  {'url': 'https://safetydata.fra.dot.gov/Office...
# 13  {'url': 'https://safetydata.fra.dot.gov/Office...
# 14  {'url': 'https://safetydata.fra.dot.gov/Office...
# 15  {'url': 'https://safetydata.fra.dot.gov/Office...
# 16  {'url': 'https://safetydata.fra.dot.gov/Office...
# 17  {'url': 'https://safetydata.fra.dot.gov/Office...
# 18  {'url': 'https://safetydata.fra.dot.gov/Office...
# 19  {'url': 'https://safetydata.fra.dot.gov/Office...
#
#    reporting_railroad_company_grouping maintenance_railroad_grouping  \
# 0                                  NaN                           NaN
# 1                            Shortline                     Shortline
# 2                            Shortline                     Shortline
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
# 5                                  NaN                           NaN
# 6                                  NaN                           NaN
# 7                                  NaN                           NaN
# 8                                  NaN                           NaN
# 9                                  NaN                           NaN
# 10                                 NaN                           NaN
# 11                                 NaN                           NaN
# 12                                 NaN                           NaN
# 13                                 NaN                           NaN
# 14                                 NaN                           NaN
# 15                                 NaN                           NaN
# 16                                 NaN                           NaN
# 17                                 NaN                           NaN
# 18                                 NaN                           NaN
# 19                                 NaN                           NaN
#
#    crossingwarningexpandedcode3 crossingwarningexpanded3  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# 5                           NaN                      NaN
# 6                           NaN                      NaN
# 7                           NaN                      NaN
# 8                           NaN                      NaN
# 9                           NaN                      NaN
# 10                          NaN                      NaN
# 11                          NaN                      NaN
# 12                          NaN                      NaN
# 13                          NaN                      NaN
# 14                            8               Stop signs
# 15                          NaN                      NaN
# 16                          NaN                      NaN
# 17                            8               Stop signs
# 18                          NaN                      NaN
# 19                           11                    Other
#
#    crossingwarningexpandedcode4 crossingwarningexpanded4
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# 5                           NaN                      NaN
# 6                           NaN                      NaN
# 7                           NaN                      NaN
# 8                           NaN                      NaN
# 9                           NaN                      NaN
# 10                          NaN                      NaN
# 11                          NaN                      NaN
# 12                          NaN                      NaN
# 13                          NaN                      NaN
# 14                          NaN                      NaN
# 15                          NaN                      NaN
# 16                          NaN                      NaN
# 17                           11                    Other
# 18                          NaN                      NaN
# 19                          NaN                      NaN
#
# [20 rows x 112 columns]

# %%
from numpy.core.fromnumeric import sort

column_headers = list(HRGC_data_raw.columns.values)

column_headers.sort()

print("The Column Headers:")
for header in column_headers:
  print(header)
# Out:
# The Column Headers:
# ampm
# cityname
# countycode
# countyname
# crossingilluminated
# crossingusersinjured
# crossinguserskilled
# crossingwarning
# crossingwarningcode
# crossingwarningexpanded1
# crossingwarningexpanded2
# crossingwarningexpanded3
# crossingwarningexpanded4
# crossingwarningexpandedcode1
# crossingwarningexpandedcode2
# crossingwarningexpandedcode3
# crossingwarningexpandedcode4
# crossingwarninglocation
# crossingwarninglocationcode
# date
# day
# district
# drivercondition
# driverconditioncode
# driverinvehicle
# driverpassedvehicle
# employeesinjured
# employeeskilled
# equipmentinvolved
# equipmentinvolvedcode
# equipmentstruck
# equipmentstruckcode
# equipmenttype
# equipmenttypecode
# estimatedrecordedspeedcode
# estimatedvehiclespeed
# form54filed
# gradecrossingid
# hazmatinvolvement
# hazmatinvolvementcode
# highwayname
# highwayuser
# highwayuseraction
# highwayuseractioncode
# highwayusercode
# highwayuserposition
# highwayuserpositioncode
# hour
# incidentmonth
# incidentnumber
# incidentyear
# maintainenanceincidentnumber
# maintenance_parent_railroad_code
# maintenance_parent_railroad_name
# maintenance_railroad_class
# maintenance_railroad_grouping
# maintenance_railroad_holding_company
# maintenance_railroad_smt_grouping
# maintenanceincidentmonth
# maintenanceincidentyear
# maintenancerailroadcode
# maintenancerailroadname
# minute
# month
# neareststation
# numberofcars
# numberoflocomotiveunits
# numbervehicleoccupants
# passengersinjured
# passengerskilled
# publicprivate
# publicprivatecode
# railroadcarunitposition
# railroadcode
# railroadname
# railroadreporting
# railroadtype
# reporting_parent_railroad_code
# reporting_parent_railroad_name
# reporting_railroad_class
# reporting_railroad_company_grouping
# reporting_railroad_holding_company
# reporting_railroad_smt_grouping
# reportkey
# statecode
# statename
# temperature
# time
# totalinjuredform55a
# totalinjuredform57
# totalkilledform55a
# totalkilledform57
# trackclass
# trackname
# tracktype
# tracktypecode
# traindirection
# traindirectioncode
# trainspeed
# url
# userstruckbysecondtraincode
# vehicledamagecost
# vehicledirection
# vehicledirectioncode
# viewobstruction
# viewobstructioncode
# visibility
# visibilitycode
# warningconnectedtosignal
# weathercondition
# weatherconditioncode
# year

# %% [markdown]
# So I extracted the colnames, but now lets try to get each label description as to better understand the measurements.
#
# I found this pdf with explainations:  [HIGHWAY-RAIL GRADE CROSSING ACCIDENT/INCIDENT
# DATA FILE STRUCTURE AND FIELD INPUT SPECIFICATIONS](https://data.transportation.gov/api/views/icqf-xf4w/files/531a212f-6b94-4403-9876-a6933a1469aa?download=true&filename=gxirfile_EFFECTIVE_060111%20(24).pdf)
#
# I will try to create a description dictionary.

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
from numpy import NaN
dictionary_data_raw = pd.read_excel('Form_57_Data_Dictionary.xlsx')

dictionary = pd.DataFrame.from_records(dictionary_data_raw)

dictionary.columns.values

dictionary = dictionary.filter(items=['Display Name', 'Description'])

print(dictionary)

# %%
# Create a dictionary to store the corresponding names and descriptions
name_to_description = {}
for index, row in dictionary.iterrows():
    name_to_description[row['Display Name']] = row['Description']

# Get the description for the variable 'report year'
description = name_to_description['Report Year']
print(description)

#Personal Prefence: Allows me to quickly pull descriptions for variable.

# %%
#Explore for NA's, missing data, and redunnacy

isnaValues = HRGC_data_raw.isna()
print(isnaValues)

# Check for NA values
missing_values = HRGC_data_raw.isna().sum()

#check for null values
missing_data = HRGC_data_raw.isnull().sum()
print(missing_data)

# Check for missing data
for column in HRGC_data_raw.columns:
    if missing_values[column] > 0:
        print(f"The column {column} has {missing_values[column]} missing values.")

# Check for redundancy
for column in HRGC_data_raw.columns:
    if HRGC_data_raw[column].duplicated().sum() > 0:
        print(f"The column {column} has {HRGC_data_raw[column].duplicated().sum()} duplicate values.")
# Out:
#     railroadcode  railroadname   year  incidentnumber  incidentyear  \
# 0          False         False  False           False         False
# 1          False         False  False           False         False
# 2          False         False  False           False         False
# 3          False         False  False           False         False
# 4          False         False  False           False         False
# 5          False         False  False           False         False
# 6          False         False  False           False         False
# 7          False         False  False           False         False
# 8          False         False  False           False         False
# 9          False         False  False           False         False
# 10         False         False  False           False         False
# 11         False         False  False           False         False
# 12         False         False  False           False         False
# 13         False         False  False           False         False
# 14         False         False  False           False         False
# 15         False         False  False           False         False
# 16         False         False  False           False         False
# 17         False         False  False           False         False
# 18         False         False  False           False         False
# 19         False         False  False           False         False
#
#     incidentmonth  maintenancerailroadcode  maintenancerailroadname  \
# 0           False                    False                    False
# 1           False                    False                    False
# 2           False                    False                    False
# 3           False                     True                     True
# 4           False                    False                    False
# 5           False                    False                    False
# 6           False                    False                    False
# 7           False                    False                    False
# 8           False                    False                    False
# 9           False                    False                    False
# 10          False                    False                    False
# 11          False                    False                    False
# 12          False                    False                    False
# 13          False                    False                    False
# 14          False                    False                    False
# 15          False                    False                    False
# 16          False                    False                    False
# 17          False                    False                    False
# 18          False                    False                    False
# 19          False                    False                    False
#
#     maintainenanceincidentnumber  maintenanceincidentyear  ...  \
# 0                          False                    False  ...
# 1                          False                    False  ...
# 2                          False                    False  ...
# 3                           True                     True  ...
# 4                          False                    False  ...
# 5                          False                    False  ...
# 6                          False                    False  ...
# 7                          False                    False  ...
# 8                          False                    False  ...
# 9                          False                    False  ...
# 10                         False                    False  ...
# 11                         False                    False  ...
# 12                         False                    False  ...
# 13                         False                    False  ...
# 14                         False                    False  ...
# 15                         False                    False  ...
# 16                         False                    False  ...
# 17                         False                    False  ...
# 18                         False                    False  ...
# 19                         False                    False  ...
#
#     maintenance_parent_railroad_code  maintenance_parent_railroad_name  \
# 0                              False                             False
# 1                              False                             False
# 2                              False                             False
# 3                               True                              True
# 4                              False                             False
# 5                              False                             False
# 6                              False                             False
# 7                              False                             False
# 8                              False                             False
# 9                              False                             False
# 10                             False                             False
# 11                             False                             False
# 12                             False                             False
# 13                             False                             False
# 14                             False                             False
# 15                             False                             False
# 16                             False                             False
# 17                             False                             False
# 18                             False                             False
# 19                             False                             False
#
#     maintenance_railroad_holding_company    url  \
# 0                                  False  False
# 1                                  False  False
# 2                                  False  False
# 3                                   True  False
# 4                                  False  False
# 5                                  False  False
# 6                                  False  False
# 7                                  False  False
# 8                                  False  False
# 9                                  False  False
# 10                                 False  False
# 11                                 False  False
# 12                                 False  False
# 13                                 False  False
# 14                                 False  False
# 15                                 False  False
# 16                                 False  False
# 17                                 False  False
# 18                                 False  False
# 19                                 False  False
#
#     reporting_railroad_company_grouping  maintenance_railroad_grouping  \
# 0                                  True                           True
# 1                                 False                          False
# 2                                 False                          False
# 3                                  True                           True
# 4                                  True                           True
# 5                                  True                           True
# 6                                  True                           True
# 7                                  True                           True
# 8                                  True                           True
# 9                                  True                           True
# 10                                 True                           True
# 11                                 True                           True
# 12                                 True                           True
# 13                                 True                           True
# 14                                 True                           True
# 15                                 True                           True
# 16                                 True                           True
# 17                                 True                           True
# 18                                 True                           True
# 19                                 True                           True
#
#     crossingwarningexpandedcode3  crossingwarningexpanded3  \
# 0                           True                      True
# 1                           True                      True
# 2                           True                      True
# 3                           True                      True
# 4                           True                      True
# 5                           True                      True
# 6                           True                      True
# 7                           True                      True
# 8                           True                      True
# 9                           True                      True
# 10                          True                      True
# 11                          True                      True
# 12                          True                      True
# 13                          True                      True
# 14                         False                     False
# 15                          True                      True
# 16                          True                      True
# 17                         False                     False
# 18                          True                      True
# 19                         False                     False
#
#     crossingwarningexpandedcode4  crossingwarningexpanded4
# 0                           True                      True
# 1                           True                      True
# 2                           True                      True
# 3                           True                      True
# 4                           True                      True
# 5                           True                      True
# 6                           True                      True
# 7                           True                      True
# 8                           True                      True
# 9                           True                      True
# 10                          True                      True
# 11                          True                      True
# 12                          True                      True
# 13                          True                      True
# 14                          True                      True
# 15                          True                      True
# 16                          True                      True
# 17                         False                     False
# 18                          True                      True
# 19                          True                      True
#
# [20 rows x 112 columns]
# railroadcode                      0
# railroadname                      0
# year                              0
# incidentnumber                    0
# incidentyear                      0
#                                  ..
# maintenance_railroad_grouping    18
# crossingwarningexpandedcode3     17
# crossingwarningexpanded3         17
# crossingwarningexpandedcode4     19
# crossingwarningexpanded4         19
# Length: 112, dtype: int64
# The column maintenancerailroadcode has 1 missing values.
# The column maintenancerailroadname has 1 missing values.
# The column maintainenanceincidentnumber has 1 missing values.
# The column maintenanceincidentyear has 1 missing values.
# The column maintenanceincidentmonth has 1 missing values.
# The column gradecrossingid has 1 missing values.
# The column cityname has 3 missing values.
# The column estimatedvehiclespeed has 2 missing values.
# The column trackclass has 1 missing values.
# The column crossingwarningexpandedcode2 has 9 missing values.
# The column crossingwarningexpanded2 has 9 missing values.
# The column crossingwarningcode has 8 missing values.
# The column crossingwarning has 8 missing values.
# The column crossingwarninglocation has 2 missing values.
# The column warningconnectedtosignal has 1 missing values.
# The column district has 1 missing values.
# The column reporting_railroad_class has 6 missing values.
# The column reporting_railroad_smt_grouping has 6 missing values.
# The column maintenance_railroad_class has 7 missing values.
# The column maintenance_railroad_smt_grouping has 7 missing values.
# The column maintenance_parent_railroad_code has 1 missing values.
# The column maintenance_parent_railroad_name has 1 missing values.
# The column maintenance_railroad_holding_company has 1 missing values.
# The column reporting_railroad_company_grouping has 18 missing values.
# The column maintenance_railroad_grouping has 18 missing values.
# The column crossingwarningexpandedcode3 has 17 missing values.
# The column crossingwarningexpanded3 has 17 missing values.
# The column crossingwarningexpandedcode4 has 19 missing values.
# The column crossingwarningexpanded4 has 19 missing values.
# The column railroadcode has 14 duplicate values.
# The column railroadname has 14 duplicate values.
# The column year has 18 duplicate values.
# The column incidentyear has 18 duplicate values.
# The column incidentmonth has 17 duplicate values.
# The column maintenancerailroadcode has 14 duplicate values.
# The column maintenancerailroadname has 14 duplicate values.
# The column maintenanceincidentyear has 18 duplicate values.
# The column maintenanceincidentmonth has 16 duplicate values.
# The column gradecrossingid has 2 duplicate values.
# The column date has 2 duplicate values.
# The column month has 17 duplicate values.
# The column day has 5 duplicate values.
# The column hour has 8 duplicate values.
# The column minute has 8 duplicate values.
# The column ampm has 18 duplicate values.
# The column neareststation has 3 duplicate values.
# The column countycode has 5 duplicate values.
# The column countyname has 5 duplicate values.
# The column statecode has 18 duplicate values.
# The column statename has 18 duplicate values.
# The column cityname has 5 duplicate values.
# The column highwayname has 3 duplicate values.
# The column publicprivatecode has 18 duplicate values.
# The column publicprivate has 18 duplicate values.
# The column highwayusercode has 16 duplicate values.
# The column highwayuser has 16 duplicate values.
# The column estimatedvehiclespeed has 9 duplicate values.
# The column vehicledirectioncode has 16 duplicate values.
# The column vehicledirection has 16 duplicate values.
# The column highwayuserpositioncode has 17 duplicate values.
# The column highwayuserposition has 17 duplicate values.
# The column equipmentinvolvedcode has 17 duplicate values.
# The column equipmentinvolved has 17 duplicate values.
# The column railroadcarunitposition has 14 duplicate values.
# The column equipmentstruckcode has 18 duplicate values.
# The column equipmentstruck has 18 duplicate values.
# The column hazmatinvolvementcode has 18 duplicate values.
# The column hazmatinvolvement has 18 duplicate values.
# The column temperature has 10 duplicate values.
# The column visibilitycode has 17 duplicate values.
# The column visibility has 17 duplicate values.
# The column weatherconditioncode has 17 duplicate values.
# The column weathercondition has 17 duplicate values.
# The column equipmenttypecode has 16 duplicate values.
# The column equipmenttype has 16 duplicate values.
# The column tracktypecode has 17 duplicate values.
# The column tracktype has 17 duplicate values.
# The column trackname has 11 duplicate values.
# The column trackclass has 15 duplicate values.
# The column numberoflocomotiveunits has 16 duplicate values.
# The column numberofcars has 3 duplicate values.
# The column trainspeed has 8 duplicate values.
# The column estimatedrecordedspeedcode has 18 duplicate values.
# The column traindirectioncode has 16 duplicate values.
# The column traindirection has 16 duplicate values.
# The column crossingwarningexpandedcode1 has 14 duplicate values.
# The column crossingwarningexpandedcode2 has 14 duplicate values.
# The column crossingwarningexpanded1 has 14 duplicate values.
# The column crossingwarningexpanded2 has 14 duplicate values.
# The column crossingwarningcode has 18 duplicate values.
# The column crossingwarning has 18 duplicate values.
# The column crossingwarninglocationcode has 17 duplicate values.
# The column crossingwarninglocation has 17 duplicate values.
# The column warningconnectedtosignal has 16 duplicate values.
# The column crossingilluminated has 17 duplicate values.
# The column userstruckbysecondtraincode has 19 duplicate values.
# The column highwayuseractioncode has 18 duplicate values.
# The column highwayuseraction has 18 duplicate values.
# The column driverpassedvehicle has 19 duplicate values.
# The column viewobstructioncode has 18 duplicate values.
# The column viewobstruction has 18 duplicate values.
# The column driverconditioncode has 17 duplicate values.
# The column drivercondition has 17 duplicate values.
# The column driverinvehicle has 18 duplicate values.
# The column crossinguserskilled has 18 duplicate values.
# The column crossingusersinjured has 17 duplicate values.
# The column vehicledamagecost has 9 duplicate values.
# The column numbervehicleoccupants has 16 duplicate values.
# The column employeeskilled has 19 duplicate values.
# The column employeesinjured has 18 duplicate values.
# The column form54filed has 18 duplicate values.
# The column passengerskilled has 19 duplicate values.
# The column passengersinjured has 19 duplicate values.
# The column totalkilledform57 has 18 duplicate values.
# The column totalinjuredform57 has 17 duplicate values.
# The column railroadtype has 18 duplicate values.
# The column railroadreporting has 19 duplicate values.
# The column totalkilledform55a has 18 duplicate values.
# The column totalinjuredform55a has 17 duplicate values.
# The column district has 18 duplicate values.
# The column reporting_railroad_class has 17 duplicate values.
# The column reporting_railroad_smt_grouping has 15 duplicate values.
# The column reporting_parent_railroad_code has 14 duplicate values.
# The column reporting_parent_railroad_name has 14 duplicate values.
# The column reporting_railroad_holding_company has 14 duplicate values.
# The column maintenance_railroad_class has 17 duplicate values.
# The column maintenance_railroad_smt_grouping has 16 duplicate values.
# The column maintenance_parent_railroad_code has 14 duplicate values.
# The column maintenance_parent_railroad_name has 14 duplicate values.
# The column maintenance_railroad_holding_company has 14 duplicate values.
# The column reporting_railroad_company_grouping has 18 duplicate values.
# The column maintenance_railroad_grouping has 18 duplicate values.
# The column crossingwarningexpandedcode3 has 17 duplicate values.
# The column crossingwarningexpanded3 has 17 duplicate values.
# The column crossingwarningexpandedcode4 has 18 duplicate values.
# The column crossingwarningexpanded4 has 18 duplicate values.

# %% [markdown]
# ### Crossing Inventory Data
#
# Found another interesting data set:https://data.transportation.gov/Railroads/Crossing-Inventory-Data-Form-71-Current/m2f8-22s6

# %%
#lets try to clean up raw data

# Calculate the percentage of missing values in each column
missing_values = HRGC_data_raw.isna().mean()

# Drop columns with more than 30% missing values
drop_list = [column for column in missing_values.index if missing_values[column] > 0.3]

# Drop the columns
HRGC_data_clean = HRGC_data_raw.drop(columns=drop_list)

print(f"\n The Raw Data Frame has {len(HRGC_data_raw.columns)} labels.")
print(f"\n The Clean Data Frame now has {len(HRGC_data_clean.columns)} labels.")
print("\n Count of labels dropped: \n", len(HRGC_data_raw.columns) - len(HRGC_data_clean.columns) )
print("\n Deleted Labels: \n", drop_list)
print("\n Cleaned Data Labels: \n", HRGC_data_clean.columns.values)

HRGC_data_clean.info()
# Out:
#  The Raw Data Frame has 112 labels.
#
#  The Clean Data Frame now has 100 labels.
#
#  Count of labels dropped:
#  12
#
#  Deleted Labels:
#  ['crossingwarningexpandedcode2', 'crossingwarningexpanded2', 'crossingwarningcode', 'crossingwarning', 'maintenance_railroad_class', 'maintenance_railroad_smt_grouping', 'reporting_railroad_company_grouping', 'maintenance_railroad_grouping', 'crossingwarningexpandedcode3', 'crossingwarningexpanded3', 'crossingwarningexpandedcode4', 'crossingwarningexpanded4']
#
#  Cleaned Data Labels:
#  ['railroadcode' 'railroadname' 'year' 'incidentnumber' 'incidentyear'
#  'incidentmonth' 'maintenancerailroadcode' 'maintenancerailroadname'
#  'maintainenanceincidentnumber' 'maintenanceincidentyear'
#  'maintenanceincidentmonth' 'gradecrossingid' 'date' 'month' 'day' 'hour'
#  'minute' 'ampm' 'time' 'neareststation' 'countycode' 'countyname'
#  'statecode' 'statename' 'cityname' 'highwayname' 'publicprivatecode'
#  'publicprivate' 'highwayusercode' 'highwayuser' 'estimatedvehiclespeed'
#  'vehicledirectioncode' 'vehicledirection' 'highwayuserpositioncode'
#  'highwayuserposition' 'equipmentinvolvedcode' 'equipmentinvolved'
#  'railroadcarunitposition' 'equipmentstruckcode' 'equipmentstruck'
#  'hazmatinvolvementcode' 'hazmatinvolvement' 'temperature'
#  'visibilitycode' 'visibility' 'weatherconditioncode' 'weathercondition'
#  'equipmenttypecode' 'equipmenttype' 'tracktypecode' 'tracktype'
#  'trackname' 'trackclass' 'numberoflocomotiveunits' 'numberofcars'
#  'trainspeed' 'estimatedrecordedspeedcode' 'traindirectioncode'
#  'traindirection' 'crossingwarningexpandedcode1'
#  'crossingwarningexpanded1' 'crossingwarninglocationcode'
#  'crossingwarninglocation' 'warningconnectedtosignal'
#  'crossingilluminated' 'userstruckbysecondtraincode'
#  'highwayuseractioncode' 'highwayuseraction' 'driverpassedvehicle'
#  'viewobstructioncode' 'viewobstruction' 'driverconditioncode'
#  'drivercondition' 'driverinvehicle' 'crossinguserskilled'
#  'crossingusersinjured' 'vehicledamagecost' 'numbervehicleoccupants'
#  'employeeskilled' 'employeesinjured' 'form54filed' 'passengerskilled'
#  'passengersinjured' 'totalkilledform57' 'totalinjuredform57'
#  'railroadtype' 'railroadreporting' 'totalkilledform55a'
#  'totalinjuredform55a' 'district' 'reportkey' 'reporting_railroad_class'
#  'reporting_railroad_smt_grouping' 'reporting_parent_railroad_code'
#  'reporting_parent_railroad_name' 'reporting_railroad_holding_company'
#  'maintenance_parent_railroad_code' 'maintenance_parent_railroad_name'
#  'maintenance_railroad_holding_company' 'url']

# %%
# importing the modules
from IPython.display import display

#HRGC_data_clean.style
#display(HRGC_data_clean)

from tabulate import tabulate
print(tabulate(HRGC_data_clean, headers = 'keys', tablefmt = 'psql'))
print(HRGC_data_clean.dtypes)
# Out:
# +----+----------------+-------------------------------------------+--------+------------------+----------------+-----------------+---------------------------+-------------------------------------------+--------------------------------+---------------------------+----------------------------+-------------------+-------------------------+---------+-------+--------+----------+--------+----------+------------------+--------------+--------------+-------------+-------------+--------------+------------------+---------------------+-----------------+-------------------+---------------+-------------------------+------------------------+--------------------+---------------------------+------------------------------+-------------------------+------------------------+---------------------------+-----------------------+---------------------------------------+-------------------------+---------------------+---------------+------------------+--------------+------------------------+--------------------+---------------------+---------------------------+-----------------+-------------+-------------------+--------------+---------------------------+----------------+--------------+------------------------------+----------------------+------------------+--------------------------------+----------------------------+-------------------------------+-----------------------------------+----------------------------+-----------------------+-------------------------------+-------------------------+---------------------+-----------------------+-----------------------+-----------------------------+-----------------------+-------------------+-------------------+-----------------------+------------------------+---------------------+--------------------------+-------------------+--------------------+---------------+--------------------+---------------------+---------------------+----------------------+----------------+---------------------+----------------------+-----------------------+------------+--------------------+----------------------------+-----------------------------------+----------------------------------+-------------------------------------------+--------------------------------------+------------------------------------+-------------------------------------------+----------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+
# |    | railroadcode   | railroadname                              |   year | incidentnumber   |   incidentyear |   incidentmonth | maintenancerailroadcode   | maintenancerailroadname                   | maintainenanceincidentnumber   |   maintenanceincidentyear |   maintenanceincidentmonth | gradecrossingid   | date                    |   month |   day |   hour |   minute | ampm   | time     | neareststation   |   countycode | countyname   |   statecode | statename   | cityname     | highwayname      | publicprivatecode   | publicprivate   | highwayusercode   | highwayuser   |   estimatedvehiclespeed |   vehicledirectioncode | vehicledirection   |   highwayuserpositioncode | highwayuserposition          |   equipmentinvolvedcode | equipmentinvolved      |   railroadcarunitposition |   equipmentstruckcode | equipmentstruck                       |   hazmatinvolvementcode | hazmatinvolvement   |   temperature |   visibilitycode | visibility   |   weatherconditioncode | weathercondition   |   equipmenttypecode | equipmenttype             |   tracktypecode | tracktype   | trackname         |   trackclass |   numberoflocomotiveunits |   numberofcars |   trainspeed | estimatedrecordedspeedcode   |   traindirectioncode | traindirection   |   crossingwarningexpandedcode1 | crossingwarningexpanded1   |   crossingwarninglocationcode | crossingwarninglocation           | warningconnectedtosignal   | crossingilluminated   | userstruckbysecondtraincode   |   highwayuseractioncode | highwayuseraction   | driverpassedvehicle   |   viewobstructioncode | viewobstruction             |   driverconditioncode | drivercondition   | driverinvehicle   |   crossinguserskilled |   crossingusersinjured |   vehicledamagecost |   numbervehicleoccupants |   employeeskilled |   employeesinjured | form54filed   |   passengerskilled |   passengersinjured |   totalkilledform57 |   totalinjuredform57 | railroadtype   |   railroadreporting |   totalkilledform55a |   totalinjuredform55a |   district | reportkey          | reporting_railroad_class   | reporting_railroad_smt_grouping   | reporting_parent_railroad_code   | reporting_parent_railroad_name            | reporting_railroad_holding_company   | maintenance_parent_railroad_code   | maintenance_parent_railroad_name          | maintenance_railroad_holding_company   | url                                                                                                                                                 |
# |----+----------------+-------------------------------------------+--------+------------------+----------------+-----------------+---------------------------+-------------------------------------------+--------------------------------+---------------------------+----------------------------+-------------------+-------------------------+---------+-------+--------+----------+--------+----------+------------------+--------------+--------------+-------------+-------------+--------------+------------------+---------------------+-----------------+-------------------+---------------+-------------------------+------------------------+--------------------+---------------------------+------------------------------+-------------------------+------------------------+---------------------------+-----------------------+---------------------------------------+-------------------------+---------------------+---------------+------------------+--------------+------------------------+--------------------+---------------------+---------------------------+-----------------+-------------+-------------------+--------------+---------------------------+----------------+--------------+------------------------------+----------------------+------------------+--------------------------------+----------------------------+-------------------------------+-----------------------------------+----------------------------+-----------------------+-------------------------------+-------------------------+---------------------+-----------------------+-----------------------+-----------------------------+-----------------------+-------------------+-------------------+-----------------------+------------------------+---------------------+--------------------------+-------------------+--------------------+---------------+--------------------+---------------------+---------------------+----------------------+----------------+---------------------+----------------------+-----------------------+------------+--------------------+----------------------------+-----------------------------------+----------------------------------+-------------------------------------------+--------------------------------------+------------------------------------+-------------------------------------------+----------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | SP             | Southern Pacific Transportation Company   |   1986 | F3166            |             86 |              05 | SP                        | Southern Pacific Transportation Company   | F3166                          |                        86 |                          5 | 762634A           | 1986-05-01T00:00:00.000 |      05 |    01 |      3 |        7 | PM     | 03:07 PM | WARREN           |          149 | WARREN       |          28 | MISSISSIPPI | WARDEN       | HWY 1948         | Y                   | Public          | G                 | School bus    |                       0 |                      4 | West               |                         1 | Stalled or stuck on crossing |                       1 | Train (units pulling)  |                         1 |                     1 | Rail equipment struck highway user    |                       2 | Rail equipment      |            65 |                2 | Day          |                      3 | Rain               |                   1 | Freight Train             |               1 | Main        | MAIN              |            3 |                         4 |             85 |           28 | E                            |                    1 | North            |                              5 | Hwy. traffic signals       |                             1 | Both sides                        | No                         | Yes                   | No                            |                       4 | Stopped on crossing | No                    |                     8 | Not obstructed              |                     3 | Uninjured         
|                      4 | West               |                         3 | Moving over crossing         |                       1 | Train (units pulling)  |                        33 |                     2 | Rail equipment struck by highway user |                       4 | Neither             |            72 |                2 | Day          |                      3 | Rain               |                   1 | Freight Train             |               2 | Yard        | SINGLE MAIN TRACK |            1 |                         1 |             41 |            5 | E                            |                    1 | North            |                              7 | Crossbucks                 |                             1 | Both sides                        | No                         | No                    | No                            |                       3 | Did not stop        | No                    |                     8 | Not obstructed              |                     3 | Uninjured         | Yes               |                     0 |                      0 |                 500 |                        1 |                 0 |                  0 | No            |                  0 |                   0 |                   0 |                    0 | 3L             |                   1 |                    0 |                     0 |          3 | MSRCCO607198606    | Class 1                    | SMT-6 - UP/KCS                    | KCS                              | Kansas City Southern Railway Company      | Kansas City Southern Railway Company | KCS                                | Kansas City Southern Railway Company      | Kansas City Southern Railway Company   | {'url': 'https://safetydata.fra.dot.gov/Officeofsafety/Publicsite/Crossing/Report.aspx?cmbyr=1986&incd=CO607&RptType=A&TxtCrossingNum=302698T'}     |
# | 19 | GSMR           | GULF AND MISSISSIPPI RAILROAD CORPORATION |   1986 | 92796            |             86 |              06 | GSMR                      | GULF AND MISSISSIPPI RAILROAD CORPORATION | 92796                          |                        86 |                          6 | 305892W           | 1986-06-21T00:00:00.000 |      06 |    21 |      5 |        0 | AM     | 05:00 AM | WEST POINT       |          025 | CLAY         |          28 | MISSISSIPPI | WEST POINT   | EISHMAN RD       | Y                   | Public          | A                 | Auto          |                      60 |                      1 | North              |                         3 | Moving over crossing         |                       1 | Train (units pulling)  |                        19 |                     2 | Rail equipment struck by highway user |                       4 | Neither             |            68 |                1 | Dawn         |                      2 | Cloudy             |                   1 | Freight Train             |               1 | Main        | MAINLINE          |            2 |                         3 |             27 |           10 | R                            |                    1 | North            |                              7 | Crossbucks                 |                             1 | Both sides                        | Unknown                    | Yes                   | No                            |                       3 | Did not stop        | No                    |                     8 | Not obstructed              |                     2 | Injured           | Yes               |                     0 |                      2 |                 500 |                        2 |                 0 |                  0 | No            |                  0 |                   0 |                   0 |                    2 | 3L             |                   1 |                    0 |                     2 |          3 | GSMR92796198606    | nan                        | nan                               | GMSR                             | Gulf And Mississippi Railroad Corporation | Not Assigned                         | GMSR                               | Gulf And Mississippi Railroad Corporation | Not Assigned                           | {'url': 'https://safetydata.fra.dot.gov/Officeofsafety/Publicsite/Crossing/Report.aspx?cmbyr=1986&incd=92796&RptType=A&TxtCrossingNum=305892W'}     |
# +----+----------------+-------------------------------------------+--------+------------------+----------------+-----------------+---------------------------+-------------------------------------------+--------------------------------+---------------------------+----------------------------+-------------------+-------------------------+---------+-------+--------+----------+--------+----------+------------------+--------------+--------------+-------------+-------------+--------------+------------------+---------------------+-----------------+-------------------+---------------+-------------------------+------------------------+--------------------+---------------------------+------------------------------+-------------------------+------------------------+---------------------------+-----------------------+---------------------------------------+-------------------------+---------------------+---------------+------------------+--------------+------------------------+--------------------+---------------------+---------------------------+-----------------+-------------+-------------------+--------------+---------------------------+----------------+--------------+------------------------------+----------------------+------------------+--------------------------------+----------------------------+-------------------------------+-----------------------------------+----------------------------+-----------------------+-------------------------------+-------------------------+---------------------+-----------------------+-----------------------+-----------------------------+-----------------------+-------------------+-------------------+-----------------------+------------------------+---------------------+--------------------------+-------------------+--------------------+---------------+--------------------+---------------------+---------------------+----------------------+----------------+---------------------+----------------------+-----------------------+------------+--------------------+----------------------------+-----------------------------------+----------------------------------+-------------------------------------------+--------------------------------------+------------------------------------+-------------------------------------------+----------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------+
# railroadcode                            object
# railroadname                            object
# year                                    object
# incidentnumber                          object
# incidentyear                            object
#                                          ...
# reporting_railroad_holding_company      object
# maintenance_parent_railroad_code        object
# maintenance_parent_railroad_name        object
# maintenance_railroad_holding_company    object
# url                                     object
# Length: 100, dtype: object

# %%
#lets gather all number type data
from tabulate import tabulate

test = HRGC_data_clean['trainspeed']
print(len(test))
test = pd.to_numeric(test, errors='coerce')
import matplotlib.pyplot as plt
test.plot()
plt.show()

HRGC_data_clean.plot.scatter(y="passengerskilled", x="numberofcars", alpha=0.5)
HRGC_data_clean.plot.scatter(y="passengerskilled", x="trainspeed", alpha=0.5)
HRGC_data_clean.plot.scatter(y="passengerskilled", x="passengersinjured", alpha=0.5)
HRGC_data_clean.plot.scatter(y="passengerskilled", x="passengerskilled", alpha=0.5)

# %%
print(set(HRGC_data_clean.railroadname))
print(len(set(HRGC_data_clean.railroadname)))

print(set(HRGC_data_clean.maintenancerailroadname))
print(len(set(HRGC_data_clean.maintenancerailroadname)))

HRGC_data_clean
# Out:
# {'MIDSOUTH RAILROAD CORPORATION', 'Columbus & Greenville Railway Company', 'Illinois Central Gulf Railroad Company', 'Southern Pacific Transportation Company', 'GULF AND MISSISSIPPI RAILROAD CORPORATION', 'SOUTHERN RAILWAY COMPANY'}
# 6
# {nan, 'MIDSOUTH RAILROAD CORPORATION', 'Columbus & Greenville Railway Company', 'Illinois Central Gulf Railroad Company', 'Southern Pacific Transportation Company', 'GULF AND MISSISSIPPI RAILROAD CORPORATION'}
# 6

# %%
#lets make a corr plot of all vars in the dataframe
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = HRGC_data_clean

corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
# !pip install pandas
# !pip install sodapy

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.transportation.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.transportation.gov,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("m2f8-22s6", limit=2000)

# Convert to pandas DataFrame
Crossing_Inventory_Data_raw__df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
print(Crossing_Inventory_Data_raw__df)

# %%
from numpy.core.fromnumeric import sort

column_headers_2 = list(Crossing_Inventory_Data_raw__df.columns.values)

column_headers_2.sort()

print("The Column Headers:")
for header in column_headers_2:
  print(header)

# %%
#Explore for NA's, missing data, and redunnacy

isnaValues = Crossing_Inventory_Data_raw__df.isna()
print(isnaValues)

# Check for NA values
missing_values = Crossing_Inventory_Data_raw__df.isna().sum()

#check for null values
missing_data = Crossing_Inventory_Data_raw__df.isnull().sum()
print(missing_data)

# Check for missing data
for column in Crossing_Inventory_Data_raw__df.columns:
    if missing_values[column] > 0:
        print(f"The column {column} has {missing_values[column]} missing values.")

# Check for redundancy
for column in Crossing_Inventory_Data_raw__df.columns:
    if Crossing_Inventory_Data_raw__df[column].duplicated().sum() > 0:
        print(f"The column {column} has {Crossing_Inventory_Data_raw__df[column].duplicated().sum()} duplicate values.")

# %%
#lets try to clean up raw data

# Calculate the percentage of missing values in each column
missing_values = Crossing_Inventory_Data_raw__df.isna().mean()

# Drop columns with more than 30% missing values
drop_list = [column for column in missing_values.index if missing_values[column] > 0.3]

# Drop the columns
CID_data_clean = Crossing_Inventory_Data_raw__df.drop(columns=drop_list)

print(f"\n The Raw Data Frame has {len(Crossing_Inventory_Data_raw__df.columns)} labels.")
print(f"\n The Clean Data Frame now has {len(Crossing_Inventory_Data_raw__df.columns)} labels.")
print("\n Count of labels dropped: \n", len(Crossing_Inventory_Data_raw__df.columns) - len(CID_data_clean.columns) )
print("\n Deleted Labels: \n", drop_list)
print("\n Cleaned Data Labels: \n", CID_data_clean.columns.values)

# %%
# importing the modules
from IPython.display import display

#HRGC_data_clean.style
display(CID_data_clean)

# %%
from tabulate import tabulate
print(tabulate(CID_data_clean, headers = 'keys', tablefmt = 'psql'))
print(CID_data_clean.dtypes)

# %%
print(CID_data_clean.columns)

test2 = CID_data_clean['trainsperweek']
print(len(test))
test = pd.to_numeric(test, errors='coerce')
import matplotlib.pyplot as plt
test.plot()
plt.show()

#CID_data_clean.plot.scatter(y="compower", x="trainsperweek", alpha=0.5)
# Out:
# Index(['revisiondate', 'railroadcode', 'railroadname',
#        'reportingagencytypecode', 'reportingagencytype', 'reasoncode',
#        'reasondescription', 'crossingid', 'crossingidsuffix',
#        'reportingagencycode',
#        ...
#        'highwaypaved', 'trackrundownstreet', 'highwaynear',
#        'smallestcrossinganglecode', 'compower', 'highwaysystemcode',
#        'highwaysystem', 'roadatcrossingtypecode', 'roadatcrossingtype',
#        'crossingonstatehighwaysystem'],
#       dtype='object', length=128)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'trainsperweek'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-ab1f12460348> in <cell line: 2>()
#       1 print(CID_data_clean.columns)
# ----> 2 test2 = CID_data_clean['trainsperweek']
#       3 print(len(test))
#       4 test = pd.to_numeric(test, errors='coerce')
#       5 import matplotlib.pyplot as plt
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'trainsperweek'

# %% [markdown]
# ### Rail Equipment Accident/Incident Data (Form 54)

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.transportation.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.transportation.gov,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("85tf-25kj", limit=2000)

# Convert to pandas DataFrame
REID = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
from numpy.core.fromnumeric import sort

column_headers_2 = list(REID.columns.values)

column_headers_2.sort()

print("The Column Headers:")
for header in column_headers_2:
  print(header)

  #Explore for NA's, missing data, and redunnacy

isnaValues = REID.isna()
print(isnaValues)

# Check for NA values
missing_values = REID.isna().sum()

#check for null values
missing_data = REID.isnull().sum()
print(missing_data)

# Check for missing data
for column in REID.columns:
    if missing_values[column] > 0:
        print(f"The column {column} has {missing_values[column]} missing values.")

# Check for redundancy
for column in REID.columns:
    if REID[column].duplicated().sum() > 0:
        print(f"The column {column} has {REID[column].duplicated().sum()} duplicate values.")

#lets try to clean up raw data

# Calculate the percentage of missing values in each column
missing_values = REID.isna().mean()

# Drop columns with more than 30% missing values
drop_list = [column for column in missing_values.index if missing_values[column] > 0.3]

# Drop the columns
REID_data_clean = REID.drop(columns=drop_list)

print(f"\n The Raw Data Frame has {len(REID.columns)} labels.")
print(f"\n The Clean Data Frame now has {len(REID.columns)} labels.")
print("\n Count of labels dropped: \n", len(REID.columns) - len(REID_data_clean.columns) )
print("\n Deleted Labels: \n", drop_list)
print("\n Cleaned Data Labels: \n", REID_data_clean.columns.values)

# %%
display(REID_data_clean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0788789fe9de> in <cell line: 1>()
# ----> 1 display(REID_data_clean)
#
# NameError: name 'REID_data_clean' is not defined

# %% [markdown]
# ### Rail Equipment Accident/Incident Data (Form 54) Subset – Unique Train Accidents (Not at Grade Crossings)

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.transportation.gov", None)

results = client.get("byy5-w977", limit=2000)

REID_NON_GRADE = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
from numpy.core.fromnumeric import sort

column_headers_2 = list(REID_NON_GRADE.columns.values)

column_headers_2.sort()

print("The Column Headers:")
for header in column_headers_2:
  print(header)

  #Explore for NA's, missing data, and redunnacy

isnaValues = REID_NON_GRADE.isna()
print(isnaValues)

# Check for NA values
missing_values = REID_NON_GRADE.isna().sum()

#check for null values
missing_data = REID_NON_GRADE.isnull().sum()
print(missing_data)

# Check for missing data
for column in REID_NON_GRADE.columns:
    if missing_values[column] > 0:
        print(f"The column {column} has {missing_values[column]} missing values.")

# Check for redundancy
for column in REID_NON_GRADE.columns:
    if REID_NON_GRADE[column].duplicated().sum() > 0:
        print(f"The column {column} has {REID_NON_GRADE[column].duplicated().sum()} duplicate values.")

#lets try to clean up raw data

# Calculate the percentage of missing values in each column
missing_values = REID_NON_GRADE.isna().mean()

# Drop columns with more than 30% missing values
drop_list = [column for column in missing_values.index if missing_values[column] > 0.3]

# Drop the columns
REID_data_clean = REID_NON_GRADE.drop(columns=drop_list)

print(f"\n The Raw Data Frame has {len(REID_NON_GRADE.columns)} labels.")
print(f"\n The Clean Data Frame now has {len(REID_NON_GRADE.columns)} labels.")
print("\n Count of labels dropped: \n", len(REID_NON_GRADE.columns) - len(REID_data_clean.columns) )
print("\n Deleted Labels: \n", drop_list)
print("\n Cleaned Data Labels: \n", CID_data_clean.columns.values)

# %%
display(REID_data_clean)
# Out:
#      reportingrailroadcode                             reportingrailroadname  \
# 0                     ASAB       Atlanta & Saint Andrews Bay Railway Company
# 1                      ARR                       Alaska Railroad Corporation
# 2                     ATSF       Atchison, Topeka & Santa Fe Railway Company
# 3                       BM                        Boston & Maine Corporation
# 4                       BN              Burlington Northern Railroad Company
# ...                    ...                                               ...
# 1995                  ARZC             Arizona & California Railroad Company
# 1996                   ATK  Amtrak (National Railroad Passenger Corporation)
# 1997                  ATSF       Atchison, Topeka & Santa Fe Railway Company
# 1998                   ALS                          Alton & Southern Railway
# 1999                   ATK  Amtrak (National Railroad Passenger Corporation)
#
#       year accidentnumber                                                url  \
# 0     1978          29878  {'url': 'https://safetydata.fra.dot.gov/Office...
# 1     1976           T111  {'url': 'https://safetydata.fra.dot.gov/Office...
# 2     1978       15078103  {'url': 'https://safetydata.fra.dot.gov/Office...
# 3     1975         750010  {'url': 'https://safetydata.fra.dot.gov/Office...
# 4     1979          CH338  {'url': 'https://safetydata.fra.dot.gov/Office...
# ...    ...            ...                                                ...
# 1995  2000         20D101  {'url': 'https://safetydata.fra.dot.gov/Office...
# 1996  2003         076834  {'url': 'https://safetydata.fra.dot.gov/Office...
# 1997  1991      010791109  {'url': 'https://safetydata.fra.dot.gov/Office...
# 1998  2011         091411  {'url': 'https://safetydata.fra.dot.gov/Office...
# 1999  2000         062410  {'url': 'https://safetydata.fra.dot.gov/Office...
#
#      accidentyear accidentmonth maintenancerailroadcode  \
# 0              78            05                    ASAB
# 1              76            12                     ARR
# 2              78            07                    ATSF
# 3              75            01                      BM
# 4              79            02                      BN
# ...           ...           ...                     ...
# 1995           00            01                    ARZC
# 1996           03            02                     ATK
# 1997           91            07                    ATSF
# 1998           11            09                     ALS
# 1999           00            06                     ATK
#
#                                maintenancerailroadname  \
# 0          Atlanta & Saint Andrews Bay Railway Company
# 1                          Alaska Railroad Corporation
# 2          Atchison, Topeka & Santa Fe Railway Company
# 3                           Boston & Maine Corporation
# 4                 Burlington Northern Railroad Company
# ...                                                ...
# 1995             Arizona & California Railroad Company
# 1996  Amtrak (National Railroad Passenger Corporation)
# 1997       Atchison, Topeka & Santa Fe Railway Company
# 1998                          Alton & Southern Railway
# 1999  Amtrak (National Railroad Passenger Corporation)
#
#      maintenanceaccidentnumber  ... reporting_railroad_holding_company  \
# 0                        29878  ...                  Genesee & Wyoming
# 1                         T111  ...                       Not Assigned
# 2                     15078103  ...               BNSF Railway Company
# 3                       750010  ...                       Not Assigned
# 4                        CH338  ...               BNSF Railway Company
# ...                        ...  ...                                ...
# 1995                    20D101  ...                  Genesee & Wyoming
# 1996                    076834  ...                             Amtrak
# 1997                 010791109  ...               BNSF Railway Company
# 1998                    091411  ...     Union Pacific Railroad Company
# 1999                    062410  ...                             Amtrak
#
#      maintenance_parent_railroad_code  \
# 0                                BAYL
# 1                                 ARR
# 2                                BNSF
# 3                                 GRS
# 4                                BNSF
# ...                               ...
# 1995                             ARZC
# 1996                              ATK
# 1997                             BNSF
# 1998                               UP
# 1999                              ATK
#
#                       maintenance_parent_railroad_name  \
# 0                               BAY LINE RAILROAD, LLC
# 1                          Alaska Railroad Corporation
# 2                                 BNSF Railway Company
# 3                      Pan Am Railways/Guilford System
# 4                                 BNSF Railway Company
# ...                                                ...
# 1995             Arizona & California Railroad Company
# 1996  Amtrak (National Railroad Passenger Corporation)
# 1997                              BNSF Railway Company
# 1998                    Union Pacific Railroad Company
# 1999  Amtrak (National Railroad Passenger Corporation)
#
#      maintenance_railroad_holding_company trackclass equipment_type_code  \
# 0                       Genesee & Wyoming        NaN                 NaN
# 1                            Not Assigned          1                   1
# 2                    BNSF Railway Company          2                   6
# 3                            Not Assigned          3                   1
# 4                    BNSF Railway Company          1                   7
# ...                                   ...        ...                 ...
# 1995                    Genesee & Wyoming          3                   1
# 1996                               Amtrak          1                   8
# 1997                 BNSF Railway Company        NaN                   8
# 1998       Union Pacific Railroad Company          1                   6
# 1999                               Amtrak          1                   7
#
#        equipmenttype reporting_railroad_smt_grouping  \
# 0                NaN                             NaN
# 1      Freight Train           SMT-7 - Commuter West
# 2        Cut of cars                    SMT-5 - BNSF
# 3      Freight Train                             NaN
# 4     Yard/switching                    SMT-5 - BNSF
# ...              ...                             ...
# 1995   Freight Train         SMT-2 - Short Line East
# 1996   Light loco(s)   SMT-1 - Amtrak, Commuter East
# 1997   Light loco(s)                    SMT-5 - BNSF
# 1998     Cut of cars         SMT-8 - Short Line West
# 1999  Yard/switching   SMT-1 - Amtrak, Commuter East
#
#      maintenance_railroad_smt_grouping     division
# 0                                  NaN          NaN
# 1                SMT-7 - Commuter West          NaN
# 2                         SMT-5 - BNSF     COLORADO
# 3                                  NaN  NEW ENGLAND
# 4                         SMT-5 - BNSF      CHICAGO
# ...                                ...          ...
# 1995           SMT-2 - Short Line East        CADIZ
# 1996     SMT-1 - Amtrak, Commuter East          MAD
# 1997                      SMT-5 - BNSF      EASTERN
# 1998           SMT-8 - Short Line West          NaN
# 1999     SMT-1 - Amtrak, Commuter East          ETR
#
# [2000 rows x 116 columns]

# %% [markdown]
# ### Injury/Illness Summary - Operational Data (Form 55)

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.transportation.gov", None)
results = client.get("m8i6-zdsy", limit=2000)

# Convert to pandas DataFrame
illnessSummary = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
from numpy.core.fromnumeric import sort

column_headers_2 = list(illnessSummary.columns.values)

column_headers_2.sort()

print("The Column Headers:")
for header in column_headers_2:
  print(header)

  #Explore for NA's, missing data, and redunnacy

isnaValues = illnessSummary.isna()
print(isnaValues)

# Check for NA values
missing_values = illnessSummary.isna().sum()

#check for null values
missing_data = illnessSummary.isnull().sum()
print(missing_data)

# Check for missing data
for column in illnessSummary.columns:
    if missing_values[column] > 0:
        print(f"The column {column} has {missing_values[column]} missing values.")

# Check for redundancy
for column in illnessSummary.columns:
    if illnessSummary[column].duplicated().sum() > 0:
        print(f"The column {column} has {illnessSummary[column].duplicated().sum()} duplicate values.")

#lets try to clean up raw data

# Calculate the percentage of missing values in each column
missing_values = illnessSummary.isna().mean()

# Drop columns with more than 30% missing values
drop_list = [column for column in missing_values.index if missing_values[column] > 0.3]

# Drop the columns
illnessSummary_data_clean = illnessSummary.drop(columns=drop_list)

print(f"\n The Raw Data Frame has {len(illnessSummary.columns)} labels.")
print(f"\n The Clean Data Frame now has {len(illnessSummary.columns)} labels.")
print("\n Count of labels dropped: \n", len(illnessSummary.columns) - len(illnessSummary_data_clean.columns) )
print("\n Deleted Labels: \n", drop_list)
print("\n Cleaned Data Labels: \n", illnessSummary_data_clean.columns.values)

# %% [markdown]
# ### Injury/Illness Summary - Casualty Data (Form 55a)

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.transportation.gov", None)

results = client.get("rash-pd2d", limit=2000)

# Convert to pandas DataFrame
illnessSummary_Casualty = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
from numpy.core.fromnumeric import sort

column_headers_2 = list(illnessSummary_Casualty.columns.values)

column_headers_2.sort()

print("The Column Headers:")
for header in column_headers_2:
  print(header)

#Explore for NA's, missing data, and redunnacy

isnaValues = illnessSummary_Casualty.isna()
print(isnaValues)

# Check for NA values
missing_values = illnessSummary_Casualty.isna().sum()

#check for null values
missing_data = illnessSummary_Casualty.isnull().sum()
print(missing_data)

# Check for missing data
for column in illnessSummary_Casualty.columns:
    if missing_values[column] > 0:
        print(f"The column {column} has {missing_values[column]} missing values.")

# Check for redundancy
for column in illnessSummary_Casualty.columns:
    if illnessSummary_Casualty[column].duplicated().sum() > 0:
        print(f"The column {column} has {illnessSummary_Casualty[column].duplicated().sum()} duplicate values.")

#lets try to clean up raw data

# Calculate the percentage of missing values in each column
missing_values = illnessSummary_Casualty.isna().mean()

# Drop columns with more than 30% missing values
drop_list = [column for column in missing_values.index if missing_values[column] > 0.3]

# Drop the columns
illnessSummary_Casualty_data_clean = illnessSummary_Casualty.drop(columns=drop_list)

print(f"\n The Raw Data Frame has {len(illnessSummary_Casualty.columns)} labels.")
print(f"\n The Clean Data Frame now has {len(illnessSummary_Casualty.columns)} labels.")
print("\n Count of labels dropped: \n", len(illnessSummary_Casualty.columns) - len(illnessSummary_data_clean.columns) )
print("\n Deleted Labels: \n", drop_list)
print("\n Cleaned Data Labels: \n", illnessSummary_Casualty_data_clean.columns.values)

# %% [markdown]
# ### HRGC_data_clean EDA
#
# > Indented block
# I want a corr plot of deaths and several vars

# %%
from tabulate import tabulate

print(tabulate(HRGC_data_clean, headers = 'keys', tablefmt = 'psql'))
# Out:
# +----+----------------+-------------------------------------------+--------+------------------+----------------+-----------------+---------------------------+-------------------------------------------+--------------------------------+---------------------------+----------------------------+-------------------+-------------------------+---------+-------+--------+----------+--------+----------+------------------+--------------+--------------+-------------+-------------+--------------+------------------+---------------------+-----------------+-------------------+---------------+-------------------------+------------------------+--------------------+---------------------------+------------------------------+-------------------------+------------------------+---------------------------+-----------------------+---------------------------------------+-------------------------+---------------------+---------------+------------------+--------------+------------------------+--------------------+---------------------+---------------------------+-----------------+-------------+-------------------+--------------+---------------------------+----------------+--------------+------------------------------+----------------------+------------------+--------------------------------+----------------------------+-------------------------------+-----------------------------------+----------------------------+-----------------------+-------------------------------+-------------------------+---------------------+-----------------------+-----------------------+-----------------------------+-----------------------+-------------------+-------------------+-----------------------+------------------------+---------------------+--------------------------+-------------------+--------------------+---------------+--------------------+---------------------+---------------------+----------------------+----------------+---------------------+----------------------+-----------------------+------------+--------------------+----------------------------+-----------------------------------+----------------------------------+-------------------------------------------+--------------------------------------+------------------------------------+-------------------------------------------+----------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------+
# |    | railroadcode   | railroadname                              |   year | incidentnumber   |   incidentyear |   incidentmonth | maintenancerailroadcode   | maintenancerailroadname                   | maintainenanceincidentnumber   |   maintenanceincidentyear |   maintenanceincidentmonth | gradecrossingid   | date                    |   month |   day |   hour |   minute | ampm   | time     | neareststation   |   countycode | countyname   |   statecode | statename   | cityname     | highwayname      | publicprivatecode   | publicprivate   | highwayusercode   | highwayuser   |   estimatedvehiclespeed |   vehicledirectioncode | vehicledirection   |   highwayuserpositioncode | highwayuserposition          |   equipmentinvolvedcode | equipmentinvolved      |   railroadcarunitposition |   equipmentstruckcode | equipmentstruck                       |   hazmatinvolvementcode | hazmatinvolvement   |   temperature |   visibilitycode | visibility   |   weatherconditioncode | weathercondition   |   equipmenttypecode | equipmenttype             |   tracktypecode | tracktype   | trackname         |   trackclass |   numberoflocomotiveunits |   numberofcars |   trainspeed | estimatedrecordedspeedcode   |   traindirectioncode | traindirection   |   crossingwarningexpandedcode1 | crossingwarningexpanded1   |   crossingwarninglocationcode | crossingwarninglocation           | warningconnectedtosignal   | crossingilluminated   | userstruckbysecondtraincode   |   highwayuseractioncode | highwayuseraction   | driverpassedvehicle   |   viewobstructioncode | viewobstruction             |   driverconditioncode | drivercondition   | driverinvehicle   |   crossinguserskilled |   crossingusersinjured |   vehicledamagecost |   numbervehicleoccupants |   employeeskilled |   employeesinjured | form54filed   |   passengerskilled |   passengersinjured |   totalkilledform57 |   totalinjuredform57 | railroadtype   |   railroadreporting |   totalkilledform55a |   totalinjuredform55a |   district | reportkey          | reporting_railroad_class   | reporting_railroad_smt_grouping   | reporting_parent_railroad_code   | reporting_parent_railroad_name            | reporting_railroad_holding_company   | maintenance_parent_railroad_code   | maintenance_parent_railroad_name          | maintenance_railroad_holding_company   | url                                                                                                                                                |
{'url': 'https://safetydata.fra.dot.gov/Officeofsafety/Publicsite/Crossing/Report.aspx?cmbyr=1986&incd=CO607&RptType=A&TxtCrossingNum=302698T'}    |
# | 19 | GSMR           | GULF AND MISSISSIPPI RAILROAD CORPORATION |   1986 | 92796            |             86 |              06 | GSMR                      | GULF AND MISSISSIPPI RAILROAD CORPORATION | 92796                          |                        86 |                          6 | 305892W           | 1986-06-21T00:00:00.000 |      06 |    21 |      5 |        0 | AM     | 05:00 AM | WEST POINT       |          025 | CLAY         |          28 | MISSISSIPPI | WEST POINT   | EISHMAN RD       | Y                   | Public          | A                 | Auto          |                      60 |                      1 | North              |                         3 | Moving over crossing         |                       1 | Train (units pulling)  |                        19 |                     2 | Rail equipment struck by highway user |                       4 | Neither             |            68 |                1 | Dawn         |                      2 | Cloudy             |                   1 | Freight Train             |               1 | Main        | MAINLINE          |            2 |                         3 |             27 |           10 | R                            |                    1 | North            |                              7 | Crossbucks                 |                             1 | Both sides                        | Unknown                    | Yes                   | No                            |                       3 | Did not stop        | No                    |                     8 | Not obstructed              |                     2 | Injured           | Yes               |                     0 |                      2 |                 500 |                        2 |                 0 |                  0 | No            |                  0 |                   0 |                   0 |                    2 | 3L             |                   1 |                    0 |                     2 |          3 | GSMR92796198606    | nan                        | nan                               | GMSR                             | Gulf And Mississippi Railroad Corporation | Not Assigned                         | GMSR                               | Gulf And Mississippi Railroad Corporation | Not Assigned                           | {'url': 'https://safetydata.fra.dot.gov/Officeofsafety/Publicsite/Crossing/Report.aspx?cmbyr=1986&incd=92796&RptType=A&TxtCrossingNum=305892W'}    |
# +----+----------------+-------------------------------------------+--------+------------------+----------------+-----------------+---------------------------+-------------------------------------------+--------------------------------+---------------------------+----------------------------+-------------------+-------------------------+---------+-------+--------+----------+--------+----------+------------------+--------------+--------------+-------------+-------------+--------------+------------------+---------------------+-----------------+-------------------+---------------+-------------------------+------------------------+--------------------+---------------------------+------------------------------+-------------------------+------------------------+---------------------------+-----------------------+---------------------------------------+-------------------------+---------------------+---------------+------------------+--------------+------------------------+--------------------+---------------------+---------------------------+-----------------+-------------+-------------------+--------------+---------------------------+----------------+--------------+------------------------------+----------------------+------------------+--------------------------------+----------------------------+-------------------------------+-----------------------------------+----------------------------+-----------------------+-------------------------------+-------------------------+---------------------+-----------------------+-----------------------+-----------------------------+-----------------------+-------------------+-------------------+-----------------------+------------------------+---------------------+--------------------------+-------------------+--------------------+---------------+--------------------+---------------------+---------------------+----------------------+----------------+---------------------+----------------------+-----------------------+------------+--------------------+----------------------------+-----------------------------------+----------------------------------+-------------------------------------------+--------------------------------------+------------------------------------+-------------------------------------------+----------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
test_vars = [HRGC_data_clean.estimatedvehiclespeed, HRGC_data_clean.numberofcars, HRGC_data_clean.trainspeed, HRGC_data_clean.crossinguserskilled, HRGC_data_clean.crossingusersinjured, HRGC_data_clean.vehicledamagecost,HRGC_data_clean.employeeskilled,HRGC_data_clean.employeesinjured    ]

target_vars = HRGC_data_clean["estimatedvehiclespeed"]
print(target_vars)
# Out:
# 0       0
# 1      45
# 2     NaN
# 3      25
# 4      25
# 5       0
# 6      27
# 7       2
# 8     NaN
# 9       0
# 10      2
# 11      7
# 12     45
# 13     40
# 14      5
# 15      0
# 16     10
# 17      5
# 18      5
# 19     60
# Name: estimatedvehiclespeed, dtype: object
